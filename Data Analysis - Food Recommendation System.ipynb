# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('dataset/dataset.csv')
df.head()
# Out:
#    Unnamed: 0                                     Nama     Kategori  \
# 0           0                                  Alpukat  Buah Buahan
# 1           1                                Guacamole  Buah Buahan
# 2           2                   Guacamole dengan Tomat  Buah Buahan
# 3           3  Guacamole dengan Tomat dan Cabe Paprika  Buah Buahan
# 4           4                              Buah Anggur  Buah Buahan
#
#    Ukuran Porsi    Kalori   Lemak Lemak Jenuh Lemak Tak Jenuh Ganda  \
# 0  100 gram (g)  160 kkal  14,66g      2,126g                1,816g
# 1         1 sdm   23 kkal   2,08g      0,302g                0,258g
# 2  100 gram (g)  116 kkal   9,94g      1,446g                1,258g
# 3     1 mangkok  266 kkal  22,72g      3,304g                2,882g
# 4  1 tanpa biji    3 kkal   0,01g      0,003g                0,002g
#
#   Lemak Tak Jenuh Tunggal Kolestrol Protein Karbohidrat  Serat   Gula Sodium  \
# 0                  9,799g       0mg      2g       8,53g   6,7g  0,66g    7mg
# 1                  1,393g       0mg   0,29g       1,24g     1g   0,1g   22mg
# 2                  6,625g       0mg   1,62g       7,64g   4,9g  1,37g  201mg
# 3                 15,129g       0mg   3,77g      17,75g  11,4g  3,31g  459mg
# 4                      0g       0mg   0,04g        0,9g     0g  0,77g    0mg
#
#   Kalium
# 0  485mg
# 1   69mg
# 2  393mg
# 3  913mg
# 4   10mg

# %% [markdown]
# # Data Assessing and Cleaning
#
# Our Goal in this process is to remove `null`, `duplicated` values and remove unused columns. After that, we want to change the value of each row except `Nama` to be numeric. We maybe going to add `measurement` column if there's multiple measurement in each column except `Nama`

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               452 non-null    int64
#  1   Nama                     452 non-null    object
#  2   Kategori                 452 non-null    object
#  3   Ukuran Porsi             452 non-null    object
#  4   Kalori                   452 non-null    object
#  5   Lemak                    452 non-null    object
#  6   Lemak Jenuh              452 non-null    object
#  7   Lemak Tak Jenuh Ganda    452 non-null    object
#  8   Lemak Tak Jenuh Tunggal  452 non-null    object
#  9   Kolestrol                452 non-null    object
#  10  Protein                  452 non-null    object
#  11  Karbohidrat              452 non-null    object
#  12  Serat                    452 non-null    object
#  13  Gula                     452 non-null    object
#  14  Sodium                   452 non-null    object
#  15  Kalium                   452 non-null    object
# dtypes: int64(1), object(15)
# memory usage: 56.6+ KB

# %% [markdown]
# The column `Unnamed: 0` seems like it's not will be used. So, we will remove it instead.

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Nama                     452 non-null    object
#  1   Kategori                 452 non-null    object
#  2   Ukuran Porsi             452 non-null    object
#  3   Kalori                   452 non-null    object
#  4   Lemak                    452 non-null    object
#  5   Lemak Jenuh              452 non-null    object
#  6   Lemak Tak Jenuh Ganda    452 non-null    object
#  7   Lemak Tak Jenuh Tunggal  452 non-null    object
#  8   Kolestrol                452 non-null    object
#  9   Protein                  452 non-null    object
#  10  Karbohidrat              452 non-null    object
#  11  Serat                    452 non-null    object
#  12  Gula                     452 non-null    object
#  13  Sodium                   452 non-null    object
#  14  Kalium                   452 non-null    object
# dtypes: object(15)
# memory usage: 53.1+ KB

# %%
df.describe()
# Out:
#                 Nama Kategori  Ukuran Porsi   Kalori  Lemak Lemak Jenuh  \
# count            452      452           452      452    452         452
# unique           401       10            58      215    264         293
# top     Sup Mie Ayam    Sayur  100 gram (g)  86 kkal  0,12g      0,026g
# freq               3      105           267        9     12          12
#
#        Lemak Tak Jenuh Ganda Lemak Tak Jenuh Tunggal Kolestrol Protein  \
# count                    452                     452       452     452
# unique                   303                     284       113     320
# top                       0g                      0g       0mg   5,25g
# freq                       8                      15       228       5
#
#        Karbohidrat Serat Gula Sodium Kalium
# count          452   452  452    452    452
# unique         287    79  230    239    265
# top             0g    0g   0g    1mg  366mg
# freq            78   167  105     31      5

# %% [markdown]
# ## Looking for Null and Duplicate data

# %%
df.isnull().any().value_counts()
# Out:
# False    15
# Name: count, dtype: int64

# %% [markdown]
# There's no null values inside the dataframe. We will continue to look for duplicates.

# %%
df.duplicated().value_counts()
# Out:
# False    401
# True      51
# Name: count, dtype: int64

# %% [markdown]
# There's found 51 duplicate values. We will remove it for better data.

# %%
df.drop_duplicates(inplace=True)
df.duplicated().value_counts()
# Out:
# False    401
# Name: count, dtype: int64

# %% [markdown]
# The name of the food must unique. So, we will continue searching duplicate values by name.

# %%
df.Nama.duplicated().value_counts()
# Out:
# Nama
# False    401
# Name: count, dtype: int64

# %% [markdown]
# ## Changing Columns into Numeric

# %%
df.head()
# Out:
#                                       Nama     Kategori  Ukuran Porsi  \
# 0                                  Alpukat  Buah Buahan  100 gram (g)
# 1                                Guacamole  Buah Buahan         1 sdm
# 2                   Guacamole dengan Tomat  Buah Buahan  100 gram (g)
# 3  Guacamole dengan Tomat dan Cabe Paprika  Buah Buahan     1 mangkok
# 4                              Buah Anggur  Buah Buahan  1 tanpa biji
#
#      Kalori   Lemak Lemak Jenuh Lemak Tak Jenuh Ganda Lemak Tak Jenuh Tunggal  \
# 0  160 kkal  14,66g      2,126g                1,816g                  9,799g
# 1   23 kkal   2,08g      0,302g                0,258g                  1,393g
# 2  116 kkal   9,94g      1,446g                1,258g                  6,625g
# 3  266 kkal  22,72g      3,304g                2,882g                 15,129g
# 4    3 kkal   0,01g      0,003g                0,002g                      0g
#
#   Kolestrol Protein Karbohidrat  Serat   Gula Sodium Kalium
# 0       0mg      2g       8,53g   6,7g  0,66g    7mg  485mg
# 1       0mg   0,29g       1,24g     1g   0,1g   22mg   69mg
# 2       0mg   1,62g       7,64g   4,9g  1,37g  201mg  393mg
# 3       0mg   3,77g      17,75g  11,4g  3,31g  459mg  913mg
# 4       0mg   0,04g        0,9g     0g  0,77g    0mg   10mg

# %% [markdown]
# ## Ukuran Porsi Column

# %%
df[['Jumlah Porsi', 'Takaran Porsi']] = df['Ukuran Porsi'].str.extract(r'(\d+) (.+)')
df.head()
# Out:
#                                       Nama     Kategori  Ukuran Porsi  \
# 0                                  Alpukat  Buah Buahan  100 gram (g)
# 1                                Guacamole  Buah Buahan         1 sdm
# 2                   Guacamole dengan Tomat  Buah Buahan  100 gram (g)
# 3  Guacamole dengan Tomat dan Cabe Paprika  Buah Buahan     1 mangkok
# 4                              Buah Anggur  Buah Buahan  1 tanpa biji
#
#      Kalori   Lemak Lemak Jenuh Lemak Tak Jenuh Ganda Lemak Tak Jenuh Tunggal  \
# 0  160 kkal  14,66g      2,126g                1,816g                  9,799g
# 1   23 kkal   2,08g      0,302g                0,258g                  1,393g
# 2  116 kkal   9,94g      1,446g                1,258g                  6,625g
# 3  266 kkal  22,72g      3,304g                2,882g                 15,129g
# 4    3 kkal   0,01g      0,003g                0,002g                      0g
#
#   Kolestrol Protein Karbohidrat  Serat   Gula Sodium Kalium Jumlah Porsi  \
# 0       0mg      2g       8,53g   6,7g  0,66g    7mg  485mg          100
# 1       0mg   0,29g       1,24g     1g   0,1g   22mg   69mg            1
# 2       0mg   1,62g       7,64g   4,9g  1,37g  201mg  393mg          100
# 3       0mg   3,77g      17,75g  11,4g  3,31g  459mg  913mg            1
# 4       0mg   0,04g        0,9g     0g  0,77g    0mg   10mg            1
#
#   Takaran Porsi
# 0      gram (g)
# 1           sdm
# 2      gram (g)
# 3       mangkok
# 4    tanpa biji

# %%
df.drop('Ukuran Porsi', axis=1, inplace=True)

# %% [markdown]
# ## Kalori

# %%
df.Kalori
# Out:
# 0      160 kkal
# 1       23 kkal
# 2      116 kkal
# 3      266 kkal
# 4        3 kkal
#          ...
# 447     37 kkal
# 448     36 kkal
# 449     38 kkal
# 450     31 kkal
# 451     41 kkal
# Name: Kalori, Length: 401, dtype: object

# %%
df[['Jumlah Kalori', 'Takaran Kalori']] = df['Kalori'].str.extract(r'(\d+) (.+)')

# %%
df['Takaran Kalori'].value_counts()
# Out:
# Takaran Kalori
# kkal    401
# Name: count, dtype: int64

# %% [markdown]
# The Measurement contains oly kkal value. It seems like we dont need to split into 2 columns. So we will rename the column instead into `Kalori (kkal)`

# %%
# df.drop('Takaran Kalori', axis=1, inplace=True)
df.rename({'Jumlah Kalori':'Kalori (kkal)'}, inplace=True, axis='columns')

# %%
df.drop('Takaran Kalori', inplace=True, axis=1)

# %% [markdown]
# We need to cast it into numeric values.

# %%
df['Kalori (kkal)'] = df['Kalori (kkal)'].str.replace(',','.').astype(np.float64)

# %%
df.head()
# Out:
#                                       Nama     Kategori    Kalori   Lemak  \
# 0                                  Alpukat  Buah Buahan  160 kkal  14,66g
# 1                                Guacamole  Buah Buahan   23 kkal   2,08g
# 2                   Guacamole dengan Tomat  Buah Buahan  116 kkal   9,94g
# 3  Guacamole dengan Tomat dan Cabe Paprika  Buah Buahan  266 kkal  22,72g
# 4                              Buah Anggur  Buah Buahan    3 kkal   0,01g
#
#   Lemak Jenuh Lemak Tak Jenuh Ganda Lemak Tak Jenuh Tunggal Kolestrol Protein  \
# 0      2,126g                1,816g                  9,799g       0mg      2g
# 1      0,302g                0,258g                  1,393g       0mg   0,29g
# 2      1,446g                1,258g                  6,625g       0mg   1,62g
# 3      3,304g                2,882g                 15,129g       0mg   3,77g
# 4      0,003g                0,002g                      0g       0mg   0,04g
#
#   Karbohidrat  Serat   Gula Sodium Kalium Jumlah Porsi Takaran Porsi  \
# 0       8,53g   6,7g  0,66g    7mg  485mg          100      gram (g)
# 1       1,24g     1g   0,1g   22mg   69mg            1           sdm
# 2       7,64g   4,9g  1,37g  201mg  393mg          100      gram (g)
# 3      17,75g  11,4g  3,31g  459mg  913mg            1       mangkok
# 4        0,9g     0g  0,77g    0mg   10mg            1    tanpa biji
#
#    Kalori (kkal)
# 0          160.0
# 1           23.0
# 2          116.0
# 3          266.0
# 4            3.0

# %% [markdown]
# ## Lemak

# %%
df.Lemak
# Out:
# 0      14,66g
# 1       2,08g
# 2       9,94g
# 3      22,72g
# 4       0,01g
#         ...
# 447     0,11g
# 448     0,11g
# 449     0,07g
# 450     0,06g
# 451     1,68g
# Name: Lemak, Length: 401, dtype: object

# %%
df[['Lemak_Amount', 'Lemak_Measurement']] = df['Lemak'].str.extract(r'([\d,.]+)([^\d,.]+)')

# %%
df.Lemak_Measurement.value_counts()
# df.drop('Lemak (g)', inplace=True, axis=1)
# Out:
# Lemak_Measurement
# g    401
# Name: count, dtype: int64

# %%
import numpy as np

df['Lemak_Amount'] = df['Lemak_Amount'].str.replace(',','.').astype(np.float64)
df.rename({"Lemak_Amount":"Lemak (g)"}, inplace=True, axis='columns')

# %%
df.drop('Lemak_Measurement', axis=1, inplace=True)

# %%
df.head()
# Out:
#                                       Nama     Kategori    Kalori   Lemak  \
# 0                                  Alpukat  Buah Buahan  160 kkal  14,66g
# 1                                Guacamole  Buah Buahan   23 kkal   2,08g
# 2                   Guacamole dengan Tomat  Buah Buahan  116 kkal   9,94g
# 3  Guacamole dengan Tomat dan Cabe Paprika  Buah Buahan  266 kkal  22,72g
# 4                              Buah Anggur  Buah Buahan    3 kkal   0,01g
#
#   Lemak Jenuh Lemak Tak Jenuh Ganda Lemak Tak Jenuh Tunggal Kolestrol Protein  \
# 0      2,126g                1,816g                  9,799g       0mg      2g
# 1      0,302g                0,258g                  1,393g       0mg   0,29g
# 2      1,446g                1,258g                  6,625g       0mg   1,62g
# 3      3,304g                2,882g                 15,129g       0mg   3,77g
# 4      0,003g                0,002g                      0g       0mg   0,04g
#
#   Karbohidrat  Serat   Gula Sodium Kalium Jumlah Porsi Takaran Porsi  \
# 0       8,53g   6,7g  0,66g    7mg  485mg          100      gram (g)
# 1       1,24g     1g   0,1g   22mg   69mg            1           sdm
# 2       7,64g   4,9g  1,37g  201mg  393mg          100      gram (g)
# 3      17,75g  11,4g  3,31g  459mg  913mg            1       mangkok
# 4        0,9g     0g  0,77g    0mg   10mg            1    tanpa biji
#
#    Kalori (kkal)  Lemak (g)
# 0          160.0      14.66
# 1           23.0       2.08
# 2          116.0       9.94
# 3          266.0      22.72
# 4            3.0       0.01

# %% [markdown]
# ## Lemak Jenuh

# %%
df['Lemak Jenuh']
# Out:
# 0      2,126g
# 1      0,302g
# 2      1,446g
# 3      3,304g
# 4      0,003g
#         ...
# 447    0,023g
# 448    0,026g
# 449    0,018g
# 450    0,017g
# 451    0,357g
# Name: Lemak Jenuh, Length: 401, dtype: object

# %%
df[['Lemak_Amount', 'Lemak_Measurement']] = df['Lemak Jenuh'].str.extract(r'([\d,.]+)([^\d,.]+)')

# %%
df.Lemak_Measurement.value_counts()
# df.drop('Lemak (g)', inplace=True, axis=1)
# Out:
# Lemak_Measurement
# g    401
# Name: count, dtype: int64

# %%
import numpy as np

df['Lemak_Amount'] = df['Lemak_Amount'].str.replace(',','.').astype(np.float64)
df.rename({"Lemak_Amount":"Lemak Jenuh (g)"}, inplace=True, axis='columns')

# %%
df.drop('Lemak_Measurement', axis=1, inplace=True)

# %%
df.head()
# Out:
#                                       Nama     Kategori    Kalori   Lemak  \
# 0                                  Alpukat  Buah Buahan  160 kkal  14,66g
# 1                                Guacamole  Buah Buahan   23 kkal   2,08g
# 2                   Guacamole dengan Tomat  Buah Buahan  116 kkal   9,94g
# 3  Guacamole dengan Tomat dan Cabe Paprika  Buah Buahan  266 kkal  22,72g
# 4                              Buah Anggur  Buah Buahan    3 kkal   0,01g
#
#   Lemak Jenuh Lemak Tak Jenuh Ganda Lemak Tak Jenuh Tunggal Kolestrol Protein  \
# 0      2,126g                1,816g                  9,799g       0mg      2g
# 1      0,302g                0,258g                  1,393g       0mg   0,29g
# 2      1,446g                1,258g                  6,625g       0mg   1,62g
# 3      3,304g                2,882g                 15,129g       0mg   3,77g
# 4      0,003g                0,002g                      0g       0mg   0,04g
#
#   Karbohidrat  Serat   Gula Sodium Kalium Jumlah Porsi Takaran Porsi  \
# 0       8,53g   6,7g  0,66g    7mg  485mg          100      gram (g)
# 1       1,24g     1g   0,1g   22mg   69mg            1           sdm
# 2       7,64g   4,9g  1,37g  201mg  393mg          100      gram (g)
# 3      17,75g  11,4g  3,31g  459mg  913mg            1       mangkok
# 4        0,9g     0g  0,77g    0mg   10mg            1    tanpa biji
#
#    Kalori (kkal)  Lemak (g)  Lemak Jenuh (g)
# 0          160.0      14.66            2.126
# 1           23.0       2.08            0.302
# 2          116.0       9.94            1.446
# 3          266.0      22.72            3.304
# 4            3.0       0.01            0.003

# %% [markdown]
# ## Lemak Tak Jenuh Ganda

# %%
df['Lemak Tak Jenuh Ganda']
# Out:
# 0      1,816g
# 1      0,258g
# 2      1,258g
# 3      2,882g
# 4      0,002g
#         ...
# 447    0,033g
# 448    0,032g
# 449    0,023g
# 450    0,018g
# 451    0,565g
# Name: Lemak Tak Jenuh Ganda, Length: 401, dtype: object

# %%
df[['Lemak_Amount', 'Lemak_Measurement']] = df['Lemak Tak Jenuh Ganda'].str.extract(r'([\d,.]+)([^\d,.]+)')

# %%
df.Lemak_Measurement.value_counts()
# df.drop('Lemak (g)', inplace=True, axis=1)
# Out:
# Lemak_Measurement
# g    401
# Name: count, dtype: int64

# %%
import numpy as np

df['Lemak_Amount'] = df['Lemak_Amount'].str.replace(',','.').astype(np.float64)
df.rename({"Lemak_Amount":"Lemak Tak Jenuh Ganda (g)"}, inplace=True, axis='columns')

# %%
df.drop('Lemak_Measurement', axis=1, inplace=True)

# %%
df.head()
# Out:
#                                       Nama     Kategori    Kalori   Lemak  \
# 0                                  Alpukat  Buah Buahan  160 kkal  14,66g
# 1                                Guacamole  Buah Buahan   23 kkal   2,08g
# 2                   Guacamole dengan Tomat  Buah Buahan  116 kkal   9,94g
# 3  Guacamole dengan Tomat dan Cabe Paprika  Buah Buahan  266 kkal  22,72g
# 4                              Buah Anggur  Buah Buahan    3 kkal   0,01g
#
#   Lemak Jenuh Lemak Tak Jenuh Ganda Lemak Tak Jenuh Tunggal Kolestrol Protein  \
# 0      2,126g                1,816g                  9,799g       0mg      2g
# 1      0,302g                0,258g                  1,393g       0mg   0,29g
# 2      1,446g                1,258g                  6,625g       0mg   1,62g
# 3      3,304g                2,882g                 15,129g       0mg   3,77g
# 4      0,003g                0,002g                      0g       0mg   0,04g
#
#   Karbohidrat  Serat   Gula Sodium Kalium Jumlah Porsi Takaran Porsi  \
# 0       8,53g   6,7g  0,66g    7mg  485mg          100      gram (g)
# 1       1,24g     1g   0,1g   22mg   69mg            1           sdm
# 2       7,64g   4,9g  1,37g  201mg  393mg          100      gram (g)
# 3      17,75g  11,4g  3,31g  459mg  913mg            1       mangkok
# 4        0,9g     0g  0,77g    0mg   10mg            1    tanpa biji
#
#    Kalori (kkal)  Lemak (g)  Lemak Jenuh (g)  Lemak Tak Jenuh Ganda (g)
# 0          160.0      14.66            2.126                      1.816
# 1           23.0       2.08            0.302                      0.258
# 2          116.0       9.94            1.446                      1.258
# 3          266.0      22.72            3.304                      2.882
# 4            3.0       0.01            0.003                      0.002

# %% [markdown]
# ## Lemak Tak Jenuh Tunggal

# %%
df['Lemak Tak Jenuh Tunggal']
# Out:
# 0       9,799g
# 1       1,393g
# 2       6,625g
# 3      15,129g
# 4           0g
#         ...
# 447     0,033g
# 448     0,023g
# 449     0,017g
# 450     0,018g
# 451     0,605g
# Name: Lemak Tak Jenuh Tunggal, Length: 401, dtype: object

# %%
df[['Lemak_Amount', 'Lemak_Measurement']] = df['Lemak Tak Jenuh Tunggal'].str.extract(r'([\d,.]+)([^\d,.]+)')

# %%
df.Lemak_Measurement.value_counts()
# df.drop('Lemak (g)', inplace=True, axis=1)
# Out:
# Lemak_Measurement
# g    401
# Name: count, dtype: int64

# %%
import numpy as np

df['Lemak_Amount'] = df['Lemak_Amount'].str.replace(',','.').astype(np.float64)
df.rename({"Lemak_Amount":"Lemak Tak Jenuh Tunggal (g)"}, inplace=True, axis='columns')

# %%
df.drop('Lemak_Measurement', axis=1, inplace=True)

# %%
df.head()
# Out:
#                                       Nama     Kategori    Kalori   Lemak  \
# 0                                  Alpukat  Buah Buahan  160 kkal  14,66g
# 1                                Guacamole  Buah Buahan   23 kkal   2,08g
# 2                   Guacamole dengan Tomat  Buah Buahan  116 kkal   9,94g
# 3  Guacamole dengan Tomat dan Cabe Paprika  Buah Buahan  266 kkal  22,72g
# 4                              Buah Anggur  Buah Buahan    3 kkal   0,01g
#
#   Lemak Jenuh Lemak Tak Jenuh Ganda Lemak Tak Jenuh Tunggal Kolestrol Protein  \
# 0      2,126g                1,816g                  9,799g       0mg      2g
# 1      0,302g                0,258g                  1,393g       0mg   0,29g
# 2      1,446g                1,258g                  6,625g       0mg   1,62g
# 3      3,304g                2,882g                 15,129g       0mg   3,77g
# 4      0,003g                0,002g                      0g       0mg   0,04g
#
#   Karbohidrat  ...   Gula Sodium Kalium Jumlah Porsi Takaran Porsi  \
# 0       8,53g  ...  0,66g    7mg  485mg          100      gram (g)
# 1       1,24g  ...   0,1g   22mg   69mg            1           sdm
# 2       7,64g  ...  1,37g  201mg  393mg          100      gram (g)
# 3      17,75g  ...  3,31g  459mg  913mg            1       mangkok
# 4        0,9g  ...  0,77g    0mg   10mg            1    tanpa biji
#
#   Kalori (kkal)  Lemak (g)  Lemak Jenuh (g)  Lemak Tak Jenuh Ganda (g)  \
# 0         160.0      14.66            2.126                      1.816
# 1          23.0       2.08            0.302                      0.258
# 2         116.0       9.94            1.446                      1.258
# 3         266.0      22.72            3.304                      2.882
# 4           3.0       0.01            0.003                      0.002
#
#    Lemak Tak Jenuh Tunggal (g)
# 0                        9.799
# 1                        1.393
# 2                        6.625
# 3                       15.129
# 4                        0.000
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Kolestrol

# %%
df['Kolestrol']
# Out:
# 0       0mg
# 1       0mg
# 2       0mg
# 3       0mg
# 4       0mg
#        ...
# 447     1mg
# 448     2mg
# 449     0mg
# 450     0mg
# 451    13mg
# Name: Kolestrol, Length: 401, dtype: object

# %%
df[['Lemak_Amount', 'Lemak_Measurement']] = df['Kolestrol'].str.extract(r'([\d,.]+)([^\d,.]+)')

# %%
df.Lemak_Measurement.value_counts()
# df.drop('Lemak (g)', inplace=True, axis=1)
# Out:
# Lemak_Measurement
# mg    385
# g      16
# Name: count, dtype: int64

# %%
import numpy as np

df['Lemak_Amount'] = df['Lemak_Amount'].str.replace(',','.').astype(np.float64)
df.rename({"Lemak_Amount":"Kolestrol (g)"}, inplace=True, axis='columns')

# %%
df.drop('Lemak_Measurement', axis=1, inplace=True)

# %%
df.head()
# Out:
#                                       Nama     Kategori    Kalori   Lemak  \
# 0                                  Alpukat  Buah Buahan  160 kkal  14,66g
# 1                                Guacamole  Buah Buahan   23 kkal   2,08g
# 2                   Guacamole dengan Tomat  Buah Buahan  116 kkal   9,94g
# 3  Guacamole dengan Tomat dan Cabe Paprika  Buah Buahan  266 kkal  22,72g
# 4                              Buah Anggur  Buah Buahan    3 kkal   0,01g
#
#   Lemak Jenuh Lemak Tak Jenuh Ganda Lemak Tak Jenuh Tunggal Kolestrol Protein  \
# 0      2,126g                1,816g                  9,799g       0mg      2g
# 1      0,302g                0,258g                  1,393g       0mg   0,29g
# 2      1,446g                1,258g                  6,625g       0mg   1,62g
# 3      3,304g                2,882g                 15,129g       0mg   3,77g
# 4      0,003g                0,002g                      0g       0mg   0,04g
#
#   Karbohidrat  ... Sodium Kalium Jumlah Porsi Takaran Porsi Kalori (kkal)  \
# 0       8,53g  ...    7mg  485mg          100      gram (g)         160.0
# 1       1,24g  ...   22mg   69mg            1           sdm          23.0
# 2       7,64g  ...  201mg  393mg          100      gram (g)         116.0
# 3      17,75g  ...  459mg  913mg            1       mangkok         266.0
# 4        0,9g  ...    0mg   10mg            1    tanpa biji           3.0
#
#   Lemak (g)  Lemak Jenuh (g)  Lemak Tak Jenuh Ganda (g)  \
# 0     14.66            2.126                      1.816
# 1      2.08            0.302                      0.258
# 2      9.94            1.446                      1.258
# 3     22.72            3.304                      2.882
# 4      0.01            0.003                      0.002
#
#    Lemak Tak Jenuh Tunggal (g)  Kolestrol (g)
# 0                        9.799            0.0
# 1                        1.393            0.0
# 2                        6.625            0.0
# 3                       15.129            0.0
# 4                        0.000            0.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Protein

# %%
df['Protein']
# Out:
# 0         2g
# 1      0,29g
# 2      1,62g
# 3      3,77g
# 4      0,04g
#        ...
# 447    1,12g
# 448     1,4g
# 449     0,8g
# 450    0,57g
# 451    6,13g
# Name: Protein, Length: 401, dtype: object

# %%
df[['Lemak_Amount', 'Lemak_Measurement']] = df['Protein'].str.extract(r'([\d,.]+)([^\d,.]+)')

# %%
df.Lemak_Measurement.value_counts()
# df.drop('Lemak (g)', inplace=True, axis=1)
# Out:
# Lemak_Measurement
# g    401
# Name: count, dtype: int64

# %%
import numpy as np

df['Lemak_Amount'] = df['Lemak_Amount'].str.replace(',','.').astype(np.float64)
df.rename({"Lemak_Amount":"Protein (g)"}, inplace=True, axis='columns')

# %%
df.drop('Lemak_Measurement', axis=1, inplace=True)

# %%
df.head()
# Out:
#                                       Nama     Kategori    Kalori   Lemak  \
# 0                                  Alpukat  Buah Buahan  160 kkal  14,66g
# 1                                Guacamole  Buah Buahan   23 kkal   2,08g
# 2                   Guacamole dengan Tomat  Buah Buahan  116 kkal   9,94g
# 3  Guacamole dengan Tomat dan Cabe Paprika  Buah Buahan  266 kkal  22,72g
# 4                              Buah Anggur  Buah Buahan    3 kkal   0,01g
#
#   Lemak Jenuh Lemak Tak Jenuh Ganda Lemak Tak Jenuh Tunggal Kolestrol Protein  \
# 0      2,126g                1,816g                  9,799g       0mg      2g
# 1      0,302g                0,258g                  1,393g       0mg   0,29g
# 2      1,446g                1,258g                  6,625g       0mg   1,62g
# 3      3,304g                2,882g                 15,129g       0mg   3,77g
# 4      0,003g                0,002g                      0g       0mg   0,04g
#
#   Karbohidrat  ... Kalium Jumlah Porsi Takaran Porsi Kalori (kkal) Lemak (g)  \
# 0       8,53g  ...  485mg          100      gram (g)         160.0     14.66
# 1       1,24g  ...   69mg            1           sdm          23.0      2.08
# 2       7,64g  ...  393mg          100      gram (g)         116.0      9.94
# 3      17,75g  ...  913mg            1       mangkok         266.0     22.72
# 4        0,9g  ...   10mg            1    tanpa biji           3.0      0.01
#
#   Lemak Jenuh (g)  Lemak Tak Jenuh Ganda (g)  Lemak Tak Jenuh Tunggal (g)  \
# 0           2.126                      1.816                        9.799
# 1           0.302                      0.258                        1.393
# 2           1.446                      1.258                        6.625
# 3           3.304                      2.882                       15.129
# 4           0.003                      0.002                        0.000
#
#    Kolestrol (g)  Protein (g)
# 0            0.0         2.00
# 1            0.0         0.29
# 2            0.0         1.62
# 3            0.0         3.77
# 4            0.0         0.04
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Karbohidrat

# %%
df['Karbohidrat']
# Out:
# 0       8,53g
# 1       1,24g
# 2       7,64g
# 3      17,75g
# 4        0,9g
#         ...
# 447     7,77g
# 448     7,15g
# 449     8,24g
# 450     6,71g
# 451        0g
# Name: Karbohidrat, Length: 401, dtype: object

# %%
df[['Lemak_Amount', 'Lemak_Measurement']] = df['Karbohidrat'].str.extract(r'([\d,.]+)([^\d,.]+)')

# %%
df.Lemak_Measurement.value_counts()
# df.drop('Lemak (g)', inplace=True, axis=1)
# Out:
# Lemak_Measurement
# g    401
# Name: count, dtype: int64

# %%
import numpy as np

df['Lemak_Amount'] = df['Lemak_Amount'].str.replace(',','.').astype(np.float64)
df.rename({"Lemak_Amount":"Karbohidrat (g)"}, inplace=True, axis='columns')

# %%
df.drop('Lemak_Measurement', axis=1, inplace=True)

# %%
df.head()
# Out:
#                                       Nama     Kategori    Kalori   Lemak  \
# 0                                  Alpukat  Buah Buahan  160 kkal  14,66g
# 1                                Guacamole  Buah Buahan   23 kkal   2,08g
# 2                   Guacamole dengan Tomat  Buah Buahan  116 kkal   9,94g
# 3  Guacamole dengan Tomat dan Cabe Paprika  Buah Buahan  266 kkal  22,72g
# 4                              Buah Anggur  Buah Buahan    3 kkal   0,01g
#
#   Lemak Jenuh Lemak Tak Jenuh Ganda Lemak Tak Jenuh Tunggal Kolestrol Protein  \
# 0      2,126g                1,816g                  9,799g       0mg      2g
# 1      0,302g                0,258g                  1,393g       0mg   0,29g
# 2      1,446g                1,258g                  6,625g       0mg   1,62g
# 3      3,304g                2,882g                 15,129g       0mg   3,77g
# 4      0,003g                0,002g                      0g       0mg   0,04g
#
#   Karbohidrat  ... Jumlah Porsi Takaran Porsi Kalori (kkal) Lemak (g)  \
# 0       8,53g  ...          100      gram (g)         160.0     14.66
# 1       1,24g  ...            1           sdm          23.0      2.08
# 2       7,64g  ...          100      gram (g)         116.0      9.94
# 3      17,75g  ...            1       mangkok         266.0     22.72
# 4        0,9g  ...            1    tanpa biji           3.0      0.01
#
#   Lemak Jenuh (g) Lemak Tak Jenuh Ganda (g)  Lemak Tak Jenuh Tunggal (g)  \
# 0           2.126                     1.816                        9.799
# 1           0.302                     0.258                        1.393
# 2           1.446                     1.258                        6.625
# 3           3.304                     2.882                       15.129
# 4           0.003                     0.002                        0.000
#
#    Kolestrol (g)  Protein (g)  Karbohidrat (g)
# 0            0.0         2.00             8.53
# 1            0.0         0.29             1.24
# 2            0.0         1.62             7.64
# 3            0.0         3.77            17.75
# 4            0.0         0.04             0.90
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Serat

# %%
df['Serat']
# Out:
# 0       6,7g
# 1         1g
# 2       4,9g
# 3      11,4g
# 4         0g
#        ...
# 447     0,2g
# 448     0,3g
# 449     0,3g
# 450     0,1g
# 451       0g
# Name: Serat, Length: 401, dtype: object

# %%
df[['Lemak_Amount', 'Lemak_Measurement']] = df['Serat'].str.extract(r'([\d,.]+)([^\d,.]+)')

# %%
df.Lemak_Measurement.value_counts()
# df.drop('Lemak (g)', inplace=True, axis=1)
# Out:
# Lemak_Measurement
# g     385
# mg     16
# Name: count, dtype: int64

# %%
import numpy as np

df['Lemak_Amount'] = df['Lemak_Amount'].str.replace(',','.').astype(np.float64)
df.rename({"Lemak_Amount":"Serat (g)"}, inplace=True, axis='columns')

# %%
df.drop('Lemak_Measurement', axis=1, inplace=True)

# %%
df.head()
# Out:
#                                       Nama     Kategori    Kalori   Lemak  \
# 0                                  Alpukat  Buah Buahan  160 kkal  14,66g
# 1                                Guacamole  Buah Buahan   23 kkal   2,08g
# 2                   Guacamole dengan Tomat  Buah Buahan  116 kkal   9,94g
# 3  Guacamole dengan Tomat dan Cabe Paprika  Buah Buahan  266 kkal  22,72g
# 4                              Buah Anggur  Buah Buahan    3 kkal   0,01g
#
#   Lemak Jenuh Lemak Tak Jenuh Ganda Lemak Tak Jenuh Tunggal Kolestrol Protein  \
# 0      2,126g                1,816g                  9,799g       0mg      2g
# 1      0,302g                0,258g                  1,393g       0mg   0,29g
# 2      1,446g                1,258g                  6,625g       0mg   1,62g
# 3      3,304g                2,882g                 15,129g       0mg   3,77g
# 4      0,003g                0,002g                      0g       0mg   0,04g
#
#   Karbohidrat  ... Takaran Porsi Kalori (kkal) Lemak (g) Lemak Jenuh (g)  \
# 0       8,53g  ...      gram (g)         160.0     14.66           2.126
# 1       1,24g  ...           sdm          23.0      2.08           0.302
# 2       7,64g  ...      gram (g)         116.0      9.94           1.446
# 3      17,75g  ...       mangkok         266.0     22.72           3.304
# 4        0,9g  ...    tanpa biji           3.0      0.01           0.003
#
#   Lemak Tak Jenuh Ganda (g) Lemak Tak Jenuh Tunggal (g)  Kolestrol (g)  \
# 0                     1.816                       9.799            0.0
# 1                     0.258                       1.393            0.0
# 2                     1.258                       6.625            0.0
# 3                     2.882                      15.129            0.0
# 4                     0.002                       0.000            0.0
#
#    Protein (g)  Karbohidrat (g)  Serat (g)
# 0         2.00             8.53        6.7
# 1         0.29             1.24        1.0
# 2         1.62             7.64        4.9
# 3         3.77            17.75       11.4
# 4         0.04             0.90        0.0
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Gula

# %%
df['Gula']
# Out:
# 0      0,66g
# 1       0,1g
# 2      1,37g
# 3      3,31g
# 4      0,77g
#        ...
# 447    1,63g
# 448    1,47g
# 449     1,7g
# 450    1,16g
# 451       0g
# Name: Gula, Length: 401, dtype: object

# %%
df[['Lemak_Amount', 'Lemak_Measurement']] = df['Gula'].str.extract(r'([\d,.]+)([^\d,.]+)')

# %%
df.Lemak_Measurement.value_counts()
# df.drop('Lemak (g)', inplace=True, axis=1)
# Out:
# Lemak_Measurement
# g    401
# Name: count, dtype: int64

# %%
import numpy as np

df['Lemak_Amount'] = df['Lemak_Amount'].str.replace(',','.').astype(np.float64)
df.rename({"Lemak_Amount":"Gula (g)"}, inplace=True, axis='columns')

# %%
df.drop('Lemak_Measurement', axis=1, inplace=True)

# %%
df.head()
# Out:
#                                       Nama     Kategori    Kalori   Lemak  \
# 0                                  Alpukat  Buah Buahan  160 kkal  14,66g
# 1                                Guacamole  Buah Buahan   23 kkal   2,08g
# 2                   Guacamole dengan Tomat  Buah Buahan  116 kkal   9,94g
# 3  Guacamole dengan Tomat dan Cabe Paprika  Buah Buahan  266 kkal  22,72g
# 4                              Buah Anggur  Buah Buahan    3 kkal   0,01g
#
#   Lemak Jenuh Lemak Tak Jenuh Ganda Lemak Tak Jenuh Tunggal Kolestrol Protein  \
# 0      2,126g                1,816g                  9,799g       0mg      2g
# 1      0,302g                0,258g                  1,393g       0mg   0,29g
# 2      1,446g                1,258g                  6,625g       0mg   1,62g
# 3      3,304g                2,882g                 15,129g       0mg   3,77g
# 4      0,003g                0,002g                      0g       0mg   0,04g
#
#   Karbohidrat  ... Kalori (kkal) Lemak (g) Lemak Jenuh (g)  \
# 0       8,53g  ...         160.0     14.66           2.126
# 1       1,24g  ...          23.0      2.08           0.302
# 2       7,64g  ...         116.0      9.94           1.446
# 3      17,75g  ...         266.0     22.72           3.304
# 4        0,9g  ...           3.0      0.01           0.003
#
#   Lemak Tak Jenuh Ganda (g) Lemak Tak Jenuh Tunggal (g) Kolestrol (g)  \
# 0                     1.816                       9.799           0.0
# 1                     0.258                       1.393           0.0
# 2                     1.258                       6.625           0.0
# 3                     2.882                      15.129           0.0
# 4                     0.002                       0.000           0.0
#
#    Protein (g)  Karbohidrat (g)  Serat (g)  Gula (g)
# 0         2.00             8.53        6.7      0.66
# 1         0.29             1.24        1.0      0.10
# 2         1.62             7.64        4.9      1.37
# 3         3.77            17.75       11.4      3.31
# 4         0.04             0.90        0.0      0.77
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Sodium

# %%
df['Sodium']
# Out:
# 0        7mg
# 1       22mg
# 2      201mg
# 3      459mg
# 4        0mg
#        ...
# 447    155mg
# 448     56mg
# 449     62mg
# 450     25mg
# 451     13mg
# Name: Sodium, Length: 401, dtype: object

# %%
df[['Lemak_Amount', 'Lemak_Measurement']] = df['Sodium'].str.extract(r'([\d,.]+)([^\d,.]+)')

# %%
df.Lemak_Measurement.value_counts()
# df.drop('Lemak (g)', inplace=True, axis=1)
# Out:
# Lemak_Measurement
# mg    385
# g      16
# Name: count, dtype: int64

# %%
import numpy as np

df['Lemak_Amount'] = df['Lemak_Amount'].str.replace(',','.').astype(np.float64)
df.rename({"Lemak_Amount":"Sodium (g)"}, inplace=True, axis='columns')

# %%
df.drop('Lemak_Measurement', axis=1, inplace=True)

# %%
df.head()
# Out:
#                                       Nama     Kategori    Kalori   Lemak  \
# 0                                  Alpukat  Buah Buahan  160 kkal  14,66g
# 1                                Guacamole  Buah Buahan   23 kkal   2,08g
# 2                   Guacamole dengan Tomat  Buah Buahan  116 kkal   9,94g
# 3  Guacamole dengan Tomat dan Cabe Paprika  Buah Buahan  266 kkal  22,72g
# 4                              Buah Anggur  Buah Buahan    3 kkal   0,01g
#
#   Lemak Jenuh Lemak Tak Jenuh Ganda Lemak Tak Jenuh Tunggal Kolestrol Protein  \
# 0      2,126g                1,816g                  9,799g       0mg      2g
# 1      0,302g                0,258g                  1,393g       0mg   0,29g
# 2      1,446g                1,258g                  6,625g       0mg   1,62g
# 3      3,304g                2,882g                 15,129g       0mg   3,77g
# 4      0,003g                0,002g                      0g       0mg   0,04g
#
#   Karbohidrat  ... Lemak (g) Lemak Jenuh (g) Lemak Tak Jenuh Ganda (g)  \
# 0       8,53g  ...     14.66           2.126                     1.816
# 1       1,24g  ...      2.08           0.302                     0.258
# 2       7,64g  ...      9.94           1.446                     1.258
# 3      17,75g  ...     22.72           3.304                     2.882
# 4        0,9g  ...      0.01           0.003                     0.002
#
#   Lemak Tak Jenuh Tunggal (g) Kolestrol (g) Protein (g)  Karbohidrat (g)  \
# 0                       9.799           0.0        2.00             8.53
# 1                       1.393           0.0        0.29             1.24
# 2                       6.625           0.0        1.62             7.64
# 3                      15.129           0.0        3.77            17.75
# 4                       0.000           0.0        0.04             0.90
#
#    Serat (g)  Gula (g)  Sodium (g)
# 0        6.7      0.66         7.0
# 1        1.0      0.10        22.0
# 2        4.9      1.37       201.0
# 3       11.4      3.31       459.0
# 4        0.0      0.77         0.0
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Kalium

# %%
df['Kalium']
# Out:
# 0      485mg
# 1       69mg
# 2      393mg
# 3      913mg
# 4       10mg
#        ...
# 447     34mg
# 448     34mg
# 449     26mg
# 450     16mg
# 451    120mg
# Name: Kalium, Length: 401, dtype: object

# %%
df[['Lemak_Amount', 'Lemak_Measurement']] = df['Kalium'].str.extract(r'([\d,.]+)([^\d,.]+)')

# %%
df.Lemak_Measurement.value_counts()
# df.drop('Lemak (g)', inplace=True, axis=1)
# Out:
# Lemak_Measurement
# mg    401
# Name: count, dtype: int64

# %%
import numpy as np

df['Lemak_Amount'] = df['Lemak_Amount'].str.replace(',','.').astype(np.float64)
df.rename({"Lemak_Amount":"Kalium (g)"}, inplace=True, axis='columns')

# %%
df.drop('Lemak_Measurement', axis=1, inplace=True)

# %%
df.head()
# Out:
#                                       Nama     Kategori    Kalori   Lemak  \
# 0                                  Alpukat  Buah Buahan  160 kkal  14,66g
# 1                                Guacamole  Buah Buahan   23 kkal   2,08g
# 2                   Guacamole dengan Tomat  Buah Buahan  116 kkal   9,94g
# 3  Guacamole dengan Tomat dan Cabe Paprika  Buah Buahan  266 kkal  22,72g
# 4                              Buah Anggur  Buah Buahan    3 kkal   0,01g
#
#   Lemak Jenuh Lemak Tak Jenuh Ganda Lemak Tak Jenuh Tunggal Kolestrol Protein  \
# 0      2,126g                1,816g                  9,799g       0mg      2g
# 1      0,302g                0,258g                  1,393g       0mg   0,29g
# 2      1,446g                1,258g                  6,625g       0mg   1,62g
# 3      3,304g                2,882g                 15,129g       0mg   3,77g
# 4      0,003g                0,002g                      0g       0mg   0,04g
#
#   Karbohidrat  ... Lemak Jenuh (g) Lemak Tak Jenuh Ganda (g)  \
# 0       8,53g  ...           2.126                     1.816
# 1       1,24g  ...           0.302                     0.258
# 2       7,64g  ...           1.446                     1.258
# 3      17,75g  ...           3.304                     2.882
# 4        0,9g  ...           0.003                     0.002
#
#   Lemak Tak Jenuh Tunggal (g) Kolestrol (g) Protein (g) Karbohidrat (g)  \
# 0                       9.799           0.0        2.00            8.53
# 1                       1.393           0.0        0.29            1.24
# 2                       6.625           0.0        1.62            7.64
# 3                      15.129           0.0        3.77           17.75
# 4                       0.000           0.0        0.04            0.90
#
#    Serat (g)  Gula (g)  Sodium (g)  Kalium (g)
# 0        6.7      0.66         7.0       485.0
# 1        1.0      0.10        22.0        69.0
# 2        4.9      1.37       201.0       393.0
# 3       11.4      3.31       459.0       913.0
# 4        0.0      0.77         0.0        10.0
#
# [5 rows x 28 columns]

# %% [markdown]
# drop the before assessed column.

# %%
df.drop(['Kalori', 'Lemak', 'Lemak Jenuh', 'Lemak Tak Jenuh Ganda', 'Lemak Tak Jenuh Tunggal', 'Kolestrol', 'Protein', 'Karbohidrat', 'Serat', 'Gula', 'Sodium', 'Kalium'], axis=1, inplace=True)

# %%
df = df.reset_index(drop=True)
df
# Out:
#                                                   Nama  \
# 0                                              Alpukat
# 1                                            Guacamole
# 2                               Guacamole dengan Tomat
# 3              Guacamole dengan Tomat dan Cabe Paprika
# 4                                          Buah Anggur
# ..                                                 ...
# 396                                              Sushi
# 397                   Sushi dengan Sayuran dan Seafood
# 398                               Sushi dengan Sayuran
# 399  Sushi dengan Sayuran yang Digulung dengan Rump...
# 400                                     Sashimi Salmon
#
#                    Kategori Jumlah Porsi Takaran Porsi  Kalori (kkal)  \
# 0               Buah Buahan          100      gram (g)          160.0
# 1               Buah Buahan            1           sdm           23.0
# 2               Buah Buahan          100      gram (g)          116.0
# 3               Buah Buahan            1       mangkok          266.0
# 4               Buah Buahan            1    tanpa biji            3.0
# ..                      ...          ...           ...            ...
# 396  Snack (Makanan Ringan)            1          buah           37.0
# 397  Snack (Makanan Ringan)            1          buah           36.0
# 398  Snack (Makanan Ringan)            1          buah           38.0
# 399  Snack (Makanan Ringan)            1          buah           31.0
# 400  Snack (Makanan Ringan)            1          buah           41.0
#
#      Lemak (g)  Lemak Jenuh (g)  Lemak Tak Jenuh Ganda (g)  \
# 0        14.66            2.126                      1.816
# 1         2.08            0.302                      0.258
# 2         9.94            1.446                      1.258
# 3        22.72            3.304                      2.882
# 4         0.01            0.003                      0.002
# ..         ...              ...                        ...
# 396       0.11            0.023                      0.033
# 397       0.11            0.026                      0.032
# 398       0.07            0.018                      0.023
# 399       0.06            0.017                      0.018
# 400       1.68            0.357                      0.565
#
#      Lemak Tak Jenuh Tunggal (g)  Kolestrol (g)  Protein (g)  Karbohidrat (g)  \
# 0                          9.799            0.0         2.00             8.53
# 1                          1.393            0.0         0.29             1.24
# 2                          6.625            0.0         1.62             7.64
# 3                         15.129            0.0         3.77            17.75
# 4                          0.000            0.0         0.04             0.90
# ..                           ...            ...          ...              ...
# 396                        0.033            1.0         1.12             7.77
# 397                        0.023            2.0         1.40             7.15
# 398                        0.017            0.0         0.80             8.24
# 399                        0.018            0.0         0.57             6.71
# 400                        0.605           13.0         6.13             0.00
#
#      Serat (g)  Gula (g)  Sodium (g)  Kalium (g)
# 0          6.7      0.66         7.0       485.0
# 1          1.0      0.10        22.0        69.0
# 2          4.9      1.37       201.0       393.0
# 3         11.4      3.31       459.0       913.0
# 4          0.0      0.77         0.0        10.0
# ..         ...       ...         ...         ...
# 396        0.2      1.63       155.0        34.0
# 397        0.3      1.47        56.0        34.0
# 398        0.3      1.70        62.0        26.0
# 399        0.1      1.16        25.0        16.0
# 400        0.0      0.00        13.0       120.0
#
# [401 rows x 16 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Since there's limitation from the data. We cannot get detailed description about food's micronutrients (i.e: Vitamins and Minerals, source of iron, Calcium etc.), which is crucial for children's development.
#
# We will consider the safest-food for children based on macronutrients only:
# - low calories ( <= 200 kkal).
# - low cholestrol foods ( <= 200 g).

# %% [markdown]
# # Before

# %%
df.Kategori.value_counts().plot.bar()
plt.show()

# %%
df.describe()
# Out:
#        Kalori (kkal)   Lemak (g)  Lemak Jenuh (g)  Lemak Tak Jenuh Ganda (g)  \
# count     401.000000  401.000000       401.000000                 401.000000
# mean      119.600998    4.841272         1.724524                   0.796828
# std       106.458351    7.523111         4.078287                   1.437650
# min         2.000000    0.010000         0.000000                   0.000000
# 25%        42.000000    0.240000         0.039000                   0.070000
# 50%        89.000000    1.410000         0.380000                   0.280000
# 75%       155.000000    6.340000         1.923000                   0.988000
# max       660.000000   64.530000        57.218000                  12.170000
#
#        Lemak Tak Jenuh Tunggal (g)  Kolestrol (g)  Protein (g)  \
# count                   401.000000     401.000000   401.000000
# mean                      1.702426      32.762678     7.657830
# std                       2.699315      82.196963     8.920366
# min                       0.000000       0.000000     0.000000
# 25%                       0.027000       0.000000     1.060000
# 50%                       0.330000       0.000000     3.300000
# 75%                       2.325000      38.000000    12.080000
# max                      15.129000    1234.000000    35.750000
#
#        Karbohidrat (g)   Serat (g)    Gula (g)   Sodium (g)   Kalium (g)
# count       401.000000  401.000000  401.000000   401.000000   401.000000
# mean         11.841746    3.175561    4.722369   230.814613   242.339152
# std          16.147788    9.847193   10.246690   307.553792   236.154557
# min           0.000000    0.000000    0.000000     0.000000     0.000000
# 25%           0.640000    0.000000    0.040000     7.000000    84.000000
# 50%           5.700000    1.100000    1.120000    90.000000   207.000000
# 75%          16.840000    2.600000    4.130000   366.000000   318.000000
# max          82.360000   83.000000   65.000000  1887.000000  1744.000000

# %%
l_calories = df['Kalori (kkal)'] < 200
l_chol = df['Kolestrol (g)'] <= 100

df = df.loc[l_calories | l_chol]

# %% [markdown]
# # After

# %%
df.describe()
# Out:
#        Kalori (kkal)   Lemak (g)  Lemak Jenuh (g)  Lemak Tak Jenuh Ganda (g)  \
# count     392.000000  392.000000       392.000000                 392.000000
# mean      115.135204    4.513036         1.594901                   0.743388
# std       103.052514    7.186352         3.933808                   1.395391
# min         2.000000    0.010000         0.000000                   0.000000
# 25%        42.000000    0.237500         0.038750                   0.065750
# 50%        86.000000    1.370000         0.356000                   0.259500
# 75%       149.250000    5.935000         1.666250                   0.926750
# max       660.000000   64.530000        57.218000                  12.170000
#
#        Lemak Tak Jenuh Tunggal (g)  Kolestrol (g)  Protein (g)  \
# count                   392.000000     392.000000   392.000000
# mean                      1.576679      27.736821     7.379974
# std                       2.548437      54.463439     8.762099
# min                       0.000000       0.000000     0.000000
# 25%                       0.026750       0.000000     1.045000
# 50%                       0.303000       0.000000     3.135000
# 75%                       2.124250      31.000000    10.957500
# max                      15.129000     400.000000    35.750000
#
#        Karbohidrat (g)   Serat (g)    Gula (g)   Sodium (g)   Kalium (g)
# count       392.000000  392.000000  392.000000   392.000000   392.000000
# mean         11.780663    3.237755    4.817041   224.307806   243.438776
# std          16.060288    9.950697   10.344179   305.736756   238.418857
# min           0.000000    0.000000    0.000000     0.000000     0.000000
# 25%           0.675000    0.000000    0.047500     6.000000    79.500000
# 50%           6.145000    1.100000    1.145000    81.500000   206.000000
# 75%          16.817500    2.700000    4.205000   344.250000   320.250000
# max          82.360000   83.000000   65.000000  1887.000000  1744.000000

# %%
df.Kategori.value_counts().plot.bar()
plt.show()

# %% [markdown]
# there seems no significant changes to the data distribution. We have finished the Data Analysis Task. We will save the result of the Data Analysis into `preprocessed_dataset.csv`

# %%
df.to_csv("dataset/preprocessed_dataset.csv")
